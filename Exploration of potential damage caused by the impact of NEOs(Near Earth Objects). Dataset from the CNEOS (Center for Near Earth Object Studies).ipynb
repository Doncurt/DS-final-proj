# %% [markdown]
# # Exploration of theorhetical potential damage caused by the impact of NEOs(Near Earth Objects).
# # Dataset from the CNEOS (Center for Near Earth Object Studies)

# %% [markdown]
# ##  Engineering features(for predictions) through formulas and  implementing calculations with the following Python libraries: Pandas, Scikit-Learn(for machine learning libraries), Matplotlib,Seaborn

# %% [markdown]
# #### Full explanation on assumptions of propeties such as angle of entry, how the extimated diameter of the NEOs were calculated, as well as: mass,density,Force in joules, Megatons(TNT),  potential damage caused, and potential to casue and extinction event can be seen at:

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(1547)
import seaborn as sns

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 361D-A6A7
#
#  Directory of C:\Users\Don\Desktop\github\exoplanets
#
# 03/31/2018  11:14 PM    <DIR>          .
# 03/31/2018  11:14 PM    <DIR>          ..
# 03/31/2018  11:14 PM    <DIR>          .ipynb_checkpoints
# 03/30/2018  02:34 PM           895,721 cneos_closeapproach_data (1).csv
# 03/31/2018  11:04 PM           768,629 Exploration of potential damage caused by the impact of NEOs(Near Earth Objects). Dataset from the CNEOS (Center for Near Earth Object Studies).ipynb
# 03/31/2018  06:12 PM           815,562 Finalized.csv
#                3 File(s)      2,479,912 bytes
#                3 Dir(s)  16,772,358,144 bytes free

# %%
df=pd.read_csv('Finalized.csv')

# %%
df_before_cleaning = pd.read_csv('')

# %%
df
# Out:
#                      Object  Close-Approach (CA) Date  \
# 0                (2016 SR2)                      2018
# 1                (2018 FU1)                      2018
# 2                (2018 FO4)                      2018
# 3                (2018 FU3)                      2018
# 4                (2018 FE4)                      2018
# 5                 (2018 FB)                      2018
# 6                (2018 FB2)                      2018
# 7               (2010 GD35)                      2018
# 8                (2018 EM4)                      2018
# 9               (2004 FG29)                      2018
# 10               (2018 ER1)                      2018
# 11                (2018 EB)                      2018
# 12               (2018 FW4)                      2018
# 13       363599 (2004 FG11)                      2018
# 14                (2014 UR)                      2018
# 15                (2016 JP)                      2018
# 16              (2012 XL16)                      2018
# 17               (2013 US3)                      2018
# 18               (2018 FV4)                      2018
# 19             (2002 JR100)                      2018
# 20              (1999 FN19)                      2018
# 21               (2016 JQ5)                      2018
# 22        388945 (2008 TZ3)                      2018
# 23               (1999 LK1)                      2018
# 24        68347 (2001 KB67)                      2018
# 25               (2013 LE7)                      2018
# 26               (2018 EJ4)                      2018
# 27             (2015 DP155)                      2018
# 28               (2017 YE5)                      2018
# 29        467309 (1996 AW1)                      2018
# ...                     ...                       ...
# 6543            (2009 FU23)                      2199
# 6544     154275 (2002 SR41)                      2199
# 6545            (2016 NJ33)                      2199
# 6546             (2014 MA6)                      2199
# 6547            (2003 SM84)                      2199
# 6548            (2017 RO17)                      2199
# 6549            (2015 DS53)                      2199
# 6550             (1996 TD9)                      2199
# 6551            (2010 TK19)                      2199
# 6552  2340 Hathor (1976 UA)                      2199
# 6553             (2009 WM1)                      2199
# 6554     216115 (2006 SU19)                      2199
# 6555      452302 (1995 YR1)                      2199
# 6556      450293 (2004 LV3)                      2199
# 6557      136849 (1998 CS1)                      2200
# 6558      337075 (1998 QC1)                      2200
# 6559            (2000 EM26)                      2200
# 6560            (2000 EB14)                      2200
# 6561            (2001 FC58)                      2200
# 6562              (2015 HK)                      2200
# 6563            (2014 GP17)                      2200
# 6564            (2013 ND15)                      2200
# 6565           (2016 CU193)                      2200
# 6566             (1998 SD9)                      2200
# 6567            (2007 TQ24)                      2200
# 6568             (2013 UG1)                      2200
# 6569      475534 (2006 TS7)                      2200
# 6570      413577 (2005 UL5)                      2200
# 6571           (2014 WT202)                      2200
# 6572     163696 (2003 EB50)                      2200
#
#       CA Distance Minimum (au)  V relative (m/s)  Estimated Diameter(meters)  \
# 0                      0.04791            7270.0                          19
# 1                      0.03129            5900.0                          14
# 2                      0.01970            6270.0                        7984
# 3                      0.04484            8410.0                          19
# 4                      0.03360           20670.0                          34
# 5                      0.01250            8480.0                          52
# 6                      0.02556            6700.0                          24
# 7                      0.03966           11600.0                          42
# 8                      0.01596            6190.0                          29
# 9                      0.00997           14920.0                          21
# 10                     0.03977            3970.0                          24
# 11                     0.02657           15060.0                         160
# 12                     0.02469           11640.0                          30
# 13                     0.04948           24520.0                         210
# 14                     0.02375            4390.0                          15
# 15                     0.03073           12750.0                         200
# 16                     0.04014            6060.0                          26
# 17                     0.02590            7690.0                         200
# 18                     0.04407            6510.0                          54
# 19                     0.02759            7680.0                          45
# 20                     0.02480            5700.0                         112
# 21                     0.00308           10430.0                        5990
# 22                     0.01664            9020.0                         270
# 23                     0.03402           10030.0                         130
# 24                     0.02442           13340.0                         360
# 25                     0.04526            1720.0                        7988
# 26                     0.01386            6190.0                         180
# 27                     0.02303            4420.0                         150
# 28                     0.03984           15470.0                         520
# 29                     0.04593           13990.0                         320
# ...                        ...               ...                         ...
# 6543                   0.04630           10530.0                         320
# 6544                   0.04295           16280.0                         320
# 6545                   0.04373            4400.0                          30
# 6546                   0.04876            4190.0                          42
# 6547                   0.04584            1890.0                          93
# 6548                   0.01045           11640.0                          20
# 6549                   0.03489           15330.0                          48
# 6550                   0.02163           12000.0                          62
# 6551                   0.04261            7170.0                          34
# 6552                   0.00315           12690.0                         300
# 6553                   0.01061           14110.0                         270
# 6554                   0.04535           18090.0                         540
# 6555                   0.01287           29760.0                         270
# 6556                   0.01598           20260.0                         540
# 6557                   0.02790           17480.0                         208
# 6558                   0.01743           15140.0                         370
# 6559                   0.03439           13610.0                         106
# 6560                   0.03515           15830.0                          76
# 6561                   0.04384           11620.0                         270
# 6562                   0.03123            8930.0                          26
# 6563                   0.03091            8330.0                          30
# 6564                   0.00282           14420.0                          50
# 6565                   0.04079           27800.0                         340
# 6566                   0.00409           10690.0                          48
# 6567                   0.01503           14270.0                         130
# 6568                   0.02600           14920.0                         118
# 6569                   0.01147           17730.0                         190
# 6570                   0.01486           18160.0                         290
# 6571                   0.04170           12000.0                         200
# 6572                   0.04643           21340.0                        1997
#
#           Mass(Kg)  Force(joules)  Megatons(TNT)                       Damage  \
# 0     6.464455e+07   2.349829e+11   17873.637471       Major extinction event
# 1     2.586159e+07   7.629169e+10   55051.865476       Major extinction event
# 2     4.796591e+15   1.503731e+19       0.000279             Large city block
# 3     6.464455e+07   2.718303e+11   15450.813842       Major extinction event
# 4     3.704315e+08   3.828409e+12    1097.061390       Continent exterminated
# 5     1.325199e+09   5.618845e+12     747.484645        Minor extiction event
# 6     1.302881e+08   4.364652e+11    9622.759481       Major extinction event
# 7     6.982629e+08   4.049925e+12    1037.056214       Continent exterminated
# 8     2.298609e+08   7.114195e+11    5903.689607       Major extinction event
# 9     8.728287e+07   6.511302e+11    6450.322834       Major extinction event
# 10    1.302881e+08   2.586219e+11   16239.921542       Major extinction event
# 11    3.860389e+10   2.906873e+14      14.448516  Entirety of Paris destroyed
# 12    2.544690e+08   1.481010e+12    2835.903275       Continent exterminated
# 13    8.728287e+10   1.070088e+15       3.924911  Entirety of Paris destroyed
# 14    3.180863e+07   6.981993e+10   60154.740998       Major extinction event
# 15    7.539822e+10   4.806637e+14       8.737918  Entirety of Paris destroyed
# 16    1.656499e+08   5.019192e+11    8367.880906       Major extinction event
# 17    7.539822e+10   2.899062e+14      14.487446  Entirety of Paris destroyed
# 18    1.484063e+09   4.830626e+12     869.452560        Minor extiction event
# 19    8.588329e+08   3.297918e+12    1273.530637       Continent exterminated
# 20    1.324113e+10   3.773723e+13     111.295918    Mount Krakatoa comparable
# 21    2.025590e+15   1.056345e+19       0.000398             Large city block
# 22    1.855079e+11   8.366406e+14       5.020076  Entirety of Paris destroyed
# 23    2.070624e+10   1.038418e+14      40.446148  Entirety of Paris destroyed
# 24    4.397224e+11   2.932949e+15       1.432006  Entirety of Paris destroyed
# 25    4.803804e+15   4.131272e+18       0.001017         Multiple city blocks
# 26    5.496531e+10   1.701176e+14      24.688801  Entirety of Paris destroyed
# 27    3.180863e+10   7.029706e+13      59.746451    Mount Krakatoa comparable
# 28    1.325199e+12   1.025042e+16       0.409739  Entirety of Paris destroyed
# 29    3.088311e+11   2.160274e+15       1.944198  Entirety of Paris destroyed
# ...            ...            ...            ...                          ...
# 6543  3.088311e+11   1.625996e+15       2.583032  Entirety of Paris destroyed
# 6544  3.088311e+11   2.513885e+15       1.670721  Entirety of Paris destroyed
# 6545  2.544690e+08   5.598318e+11    7502.253210       Major extinction event
# 6546  6.982629e+08   1.462861e+12    2871.086417       Continent exterminated
# 6547  7.580886e+09   7.163937e+12     586.269780        Minor extiction event
# 6548  7.539822e+07   4.388177e+11    9571.173554       Major extinction event
# 6549  1.042305e+09   7.989268e+12     525.705223        Minor extiction event
# 6550  2.246188e+09   1.347713e+13     311.639030        Minor extiction event
# 6551  3.704315e+08   1.327997e+12    3162.658150       Continent exterminated
# 6552  2.544690e+11   1.614606e+15       2.601254  Entirety of Paris destroyed
# 6553  1.855079e+11   1.308758e+15       3.209149  Entirety of Paris destroyed
# 6554  1.484063e+12   1.342335e+16       0.312888  Entirety of Paris destroyed
# 6555  1.855079e+11   2.760358e+15       1.521542  Entirety of Paris destroyed
# 6556  1.484063e+12   1.503356e+16       0.279375  Entirety of Paris destroyed
# 6557  8.481275e+10   7.412634e+14       5.666002  Entirety of Paris destroyed
# 6558  4.773933e+11   3.613867e+15       1.162190  Entirety of Paris destroyed
# 6559  1.122506e+10   7.638654e+13      54.983507    Mount Krakatoa comparable
# 6560  4.137251e+09   3.274634e+13     128.258592    Mount Krakatoa comparable
# 6561  1.855079e+11   1.077801e+15       3.896824  Entirety of Paris destroyed
# 6562  1.656499e+08   7.396268e+11    5678.539562       Major extinction event
# 6563  2.544690e+08   1.059863e+12    3962.774805       Continent exterminated
# 6564  1.178097e+09   8.494081e+12     494.461959        Minor extiction event
# 6565  3.704315e+11   5.148997e+15       0.815693  Entirety of Paris destroyed
# 6566  1.042305e+09   5.571120e+12     753.887845        Minor extiction event
# 6567  2.070624e+10   1.477390e+14      28.428512  Entirety of Paris destroyed
# 6568  1.548521e+10   1.155197e+14      36.357441  Entirety of Paris destroyed
# 6569  6.464455e+10   5.730740e+14       7.328897  Entirety of Paris destroyed
# 6570  2.298609e+11   2.087137e+15       2.012326  Entirety of Paris destroyed
# 6571  7.539822e+10   4.523893e+14       9.284038  Entirety of Paris destroyed
# 6572  7.505944e+13   8.008842e+17       0.005244       Levels half large city
#
#       Extinction
# 0              1
# 1              1
# 2              0
# 3              1
# 4              0
# 5              0
# 6              1
# 7              0
# 8              1
# 9              1
# 10             1
# 11             0
# 12             0
# 13             0
# 14             1
# 15             0
# 16             1
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# 22             0
# 23             0
# 24             0
# 25             0
# 26             0
# 27             0
# 28             0
# 29             0
# ...          ...
# 6543           0
# 6544           0
# 6545           1
# 6546           0
# 6547           0
# 6548           1
# 6549           0
# 6550           0
# 6551           0
# 6552           0
# 6553           0
# 6554           0
# 6555           0
# 6556           0
# 6557           0
# 6558           0
# 6559           0
# 6560           0
# 6561           0
# 6562           1
# 6563           0
# 6564           0
# 6565           0
# 6566           0
# 6567           0
# 6568           0
# 6569           0
# 6570           0
# 6571           0
# 6572           0
#
# [6573 rows x 10 columns]

# %%
df.describe()
# Out:
#        Close-Approach (CA) Date  CA Distance Minimum (au)  V relative (m/s)  \
# count               6573.000000               6573.000000       6573.000000
# mean                2096.251331                  0.027733      11027.130686
# std                   50.684674                  0.013611       6007.204384
# min                 2018.000000                  0.000000        450.000000
# 25%                 2054.000000                  0.016890       6620.000000
# 50%                 2089.000000                  0.028940       9640.000000
# 75%                 2136.000000                  0.039340      14330.000000
# max                 2200.000000                  0.049990      41970.000000
#
#        Estimated Diameter(meters)      Mass(Kg)  Force(joules)  Megatons(TNT)  \
# count                 6573.000000  6.573000e+03   6.573000e+03    6573.000000
# mean                   744.757797  2.772881e+14   1.034649e+18    5115.472350
# std                   1878.117916  1.088642e+15   4.495060e+18   15423.232019
# min                     13.000000  2.070624e+07   1.836173e+10       0.000070
# 25%                     39.000000  5.590684e+08   2.139354e+12       1.833819
# 50%                    130.000000  2.070624e+10   1.187730e+14      35.361579
# 75%                    320.000000  3.088311e+11   2.290302e+15    1963.209666
# max                   8987.000000  6.840933e+15   6.016003e+19  228736.624162
#
#         Extinction
# count  6573.000000
# mean      0.181500
# std       0.385461
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# ## Initial part of the data exploration, just the base decriptive stats

# %%
df['CA Distance Minimum (au)'].describe() # Median and mean are pretty close
# Out:
# count    6573.000000
# mean        0.027733
# std         0.013611
# min         0.000000
# 25%         0.016890
# 50%         0.028940
# 75%         0.039340
# max         0.049990
# Name: CA Distance Minimum (au), dtype: float64

# %%
df['V relative (m/s)'].describe() #ok so the mean and the median are pretty close
# Out:
# count     6573.000000
# mean     11027.130686
# std       6007.204384
# min        450.000000
# 25%       6620.000000
# 50%       9640.000000
# 75%      14330.000000
# max      41970.000000
# Name: V relative (m/s), dtype: float64

# %%
df['Close-Approach (CA) Date'].describe() #No repeats and must section off by groups
# Out:
# count    6573.000000
# mean     2096.251331
# std        50.684674
# min      2018.000000
# 25%      2054.000000
# 50%      2089.000000
# 75%      2136.000000
# max      2200.000000
# Name: Close-Approach (CA) Date, dtype: float64

# %%
df['Estimated Diameter(meters)'].describe()# huuuuuge standard deviation and mean and media are skewed
# Out:
# count    6573.000000
# mean      744.757797
# std      1878.117916
# min        13.000000
# 25%        39.000000
# 50%       130.000000
# 75%       320.000000
# max      8987.000000
# Name: Estimated Diameter(meters), dtype: float64

# %%
df['Mass(Kg)'].describe() # becuase of the massive scales of how this works( and for te sake of NOT doing densities)
# Out:
# count    6.573000e+03
# mean     2.772881e+14
# std      1.088642e+15
# min      2.070624e+07
# 25%      5.590684e+08
# 50%      2.070624e+10
# 75%      3.088311e+11
# max      6.840933e+15
# Name: Mass(Kg), dtype: float64

# %%
df['Force(joules)'].describe() # mean and media are close enough but
# Out:
# count    6.573000e+03
# mean     1.034649e+18
# std      4.495060e+18
# min      1.836173e+10
# 25%      2.139354e+12
# 50%      1.187730e+14
# 75%      2.290302e+15
# max      6.016003e+19
# Name: Force(joules), dtype: float64

# %%
df['Megatons(TNT)'].describe()
# Out:
# count      6573.000000
# mean       5115.472350
# std       15423.232019
# min           0.000070
# 25%           1.833819
# 50%          35.361579
# 75%        1963.209666
# max      228736.624162
# Name: Megatons(TNT), dtype: float64

# %%
df['Damage'].describe()
# Out:
# count    6522.000000
# mean        6.064091
# std         2.108221
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         8.000000
# max         9.000000
# Name: Damage, dtype: float64

# %%
df['Extinction'].value_counts()
# Out:
# 0    6573
# Name: Extinction, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6573 entries, 0 to 6572
# Data columns (total 10 columns):
# Object                        6573 non-null object
# Close-Approach (CA) Date      6573 non-null int64
# CA Distance Minimum (au)      6573 non-null float64
# V relative (m/s)              6573 non-null float64
# Estimated Diameter(meters)    6573 non-null int64
# Mass(Kg)                      6573 non-null float64
# Force(joules)                 6573 non-null float64
# Megatons(TNT)                 6573 non-null float64
# Damage                        6522 non-null float64
# Extinction                    6573 non-null int64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 513.6+ KB

# %% [markdown]
# ## Visializations

# %%
sns.countplot(y='Damage', data=df,orient='h')
#counts of the level of damage don

# %%
plt.figure(figsize=(8,100))
sns.countplot(y='Close-Approach (CA) Date', data=df,orient='h')
#counts of the totql number of occurences by year

# %%
sns.heatmap(df.corr()) 
# highest correclation between extinction events and megatons of TNT as expected

# %%
# as expected( and due to the heavy amount of math in calculating the features) there is a direct correclaton between force/ 
# velocity and mass

# %%
plt.scatter(df['Force(joules)'], df['CA Distance Minimum (au)'])
#based on these it loos like theres no correlation between the distance and the amount of force, which makes sense given the
#spread of astreroids

# %%
sns.countplot(y='Extinction', data=df,orient='v')
#Just under 1 out of every 6 impacts will create an extinction event

# %%
group_by_date = pd.cut(df['Close-Approach (CA) Date'], np.arange(2018, 2200, 50))
date_grouping = df.groupby(group_by_date).mean()
date_grouping['Extinction'].plot.bar()
#most likely dates of extinctions ranges

# %%
f, ax = plt.subplots(figsize=(20, 200))
sns.countplot(y=df['Close-Approach (CA) Date'], hue=df['Damage'], orient='v');
#right click to open on a

# %%
sns.lmplot(x='Megatons(TNT)', y='Close-Approach (CA) Date',col="Extinction",data=df)

# %% [markdown]
# ## Models and Training

# %% [markdown]
# ## Decision Tree, to make sure that the model can predict the correct outcomes

# %%
# Startting the decision tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

#lets not use the original for the this
DT_df =df
columns= DT_df.columns
DT_df=pd.DataFrame(np.array(DT_df), columns=columns)
DT_df=DT_df.fillna("")
#slicing a pandas dataframe always results in a 2d arrat so must use list then.vales
labels = DT_df.Damage
DT_df=DT_df.drop(['Damage'], axis=1)
DT_df=DT_df.drop(['Object'], axis=1)


X_train, X_test, y_train, y_test = train_test_split(DT_df, list(labels.values))
clf = tree.DecisionTreeClassifier()
clf.fit(X_train, y_train)
test_pred = clf.predict(X_test)
#must set averages to none for this data due to labels are not binary, but probably one-hot encoded.
f1_score(test_pred,y_test,average=None)
print('The Decision tree classifier made predictions {0} % of the time on this data accurately'.format(100*accuracy_score(y_test,test_pred)))
# Out:
# The Decision tree classifier made predictions 99.87834549878345 % of the time on this data accurately

# %% [markdown]
# ##  K-Nearest Neighbors modeling

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
KNN_df= df

columns= KNN_df.columns
KNN_df=pd.DataFrame(np.array(KNN_df), columns=columns)
KNN_df=KNN_df.fillna("")
lables_knn= KNN_df.Damage
KNN_df=KNN_df.drop(['Damage'], axis=1)
KNN_df=KNN_df.drop(['Object'], axis=1)

scaler_KNN = StandardScaler()
scaler_KNN.fit(KNN_df)
KNN_scaled= scaler_KNN.transform(KNN_df)

X_train_KNN, X_test_KNN, y_train_KNN, y_test_KNN = train_test_split(KNN_scaled, list(lables_knn.values), test_size=0.5)
clf_KNN= KNeighborsClassifier(n_neighbors=3)
clf_KNN.fit(X_train_KNN, y_train_KNN)
test_pred = clf_KNN.predict(X_test_KNN)
neighbor = KNeighborsClassifier(n_neighbors=10)
neighbor.fit(X_train_KNN, y_train_KNN)
test_pred_KNN = clf_KNN.predict(X_test_KNN)
accuracy = accuracy_score(y_test_KNN, test_pred_KNN, normalize=True, sample_weight = None)
print("The accuraccy of predicting what type of astroids destroyed what size area utilizing KNN is % {0}".format(100*accuracy))
# Out:
# The accuraccy of predicting what type of astroids destroyed what size area utilizing KNN is % 71.8892607240645

# %% [markdown]
# ## Naive Bayes Gaussian:
# ## This is based on prior knowledge of all of the other features that might be related to the An extinction level event happening.

# %%
from sklearn.naive_bayes import GaussianNB
NB_df = df
NB_df= KNN_df
#dropping off extinction as it has too much of a correlation with wheter or not there is an extinction event
NB_target = NB_df['Extinction']
NB_df =NB_df.drop('Extinction', axis=1)
# Scaling to make data more tight for processing
scaler_NB= StandardScaler()
# X_train_NB, X_test_NB, y_train_NB, y_test_NB = train_test_split(data1, NB_target, test_size=0.5)
scaler_NB.fit(NB_df)
NB_scaled=scaler_NB.transform(NB_df)
#Fitting to models
X_train_NB, X_test_NB, y_train_NB, y_test_NB = train_test_split(NB_scaled, NB_target, test_size=0.5)
clf_NB = GaussianNB()
clf_NB.fit(X_train_NB,y_train_NB)
prediction =clf_NB.predict(X_test_NB)

print("Accuraccy of predicting an Extintion level event giving the parameters and using Naive Bayes is {}%"
      .format(100*accuracy_score(y_test_NB, prediction)))
print("f1 score For this set is: {}".format(f1_score(y_test_NB, prediction, average=None)))
# Out:
# Accuraccy of predicting an Extintion level event giving the parameters and using Naive Bayes is 84.21052631578947%
# f1 score For this set is: [ 0.8930999   0.69808028]

# %%
#KFold Cross Validvation
from sklearn.cross_validation import KFold, cross_val_score
#define a kfold which takes in the lenth of the training set, shffles and has a set number of folds in this case 5
k_fold = KFold(len( NB_target), n_folds=10, shuffle=True, random_state=0)
#declare the classifier type as gaussian
clf= GaussianNB()
#print the folds as percentages, should print 5
# print( cross_val_score(clf_NB, NB_scaled, NB_target, cv=k_fold, n_jobs=1) )
print('KFold Cross Validation with ten folds gives us ten scores of\n {}'.format(100*cross_val_score(clf_NB, NB_scaled, NB_target, cv=k_fold, n_jobs=1)))
# Out:
# KFold Cross Validation with ten folds gives us ten scores of
#  [ 100.  100.  100.  100.  100.  100.  100.  100.  100.  100.]

# %% [markdown]
# ## PCA analysis:

# %%
# For this one we need to make use of our heatmap to fin features with a high correlation
sns.heatmap(df.corr())

# %%
# The highest are of course the engineered features as three of them are directly dependent/ calculated from eachother
from sklearn.decomposition import PCA
PCA_data=df
PCA_labels= PCA_data.Damage
PCA_data= PCA_data.drop('Object', axis=1)
PCA_data=PCA_data.drop('Damage',axis=1)
scaler_PCA = StandardScaler()
scaler_PCA.fit(PCA_data)
scaled_X_PCA = scaler_PCA.transform(PCA_data)
pca = PCA()
pca.fit(scaled_X_PCA)
X_with_pca = pca.transform(scaled_X_PCA)

# %%
PCA_dictionary = dict(zip(PCA_data.columns, pca.explained_variance_ratio_))
PCA_dictionary
for name,variance in PCA_dictionary.items():
    print("For the {} label, the explained variance is {} ".format(name,variance))
# Out:
# For the Close-Approach (CA) Date label, the explained variance is 0.36311148870144516
# For the CA Distance Minimum (au) label, the explained variance is 0.244713966075111
# For the V relative (m/s) label, the explained variance is 0.11903723009449929
# For the Estimated Diameter(meters) label, the explained variance is 0.11312877855063594
# For the Mass(Kg) label, the explained variance is 0.09111052855168561
# For the Force(joules) label, the explained variance is 0.04363071873515941
# For the Megatons(TNT) label, the explained variance is 0.018845490535215788
# For the Extinction label, the explained variance is 0.006421798756247714
